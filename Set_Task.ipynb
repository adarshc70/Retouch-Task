# %%
# --- Initial Student Data ---
students = {
    "101": {"name": "Adarsh", "subjects": {"Python", "machine learner"}},
    "102": {"name": "Tanu", "subjects": {"kannada", "BIOLOGY"}},
    "103": {"name": "Arjun", "subjects": {"Social Science", "Chemistry"}},
}
 
print("\n--- Initial Student Records ---")
for r, d in students.items():
    print(r, d)
 
 
# --- Add a New Student ---
students["104"] = {
    "name": "VEEREESH",
    "subjects": {"docker", "Bash"}
}
 
print("\n--- After Adding New Student (104) ---")
for r, d in students.items():
    print(r, d)
 
 
# --- Update Existing Student ---
# Updating subjects for roll 102
students["102"]["subjects"].add("BIOLOGY")
students["102"]["name"] = "KISHAN"
 
print("\n--- After Updating Student (102) ---")
for r, d in students.items():
    print(r, d)
 
 
# --- Remove a Student ---
students.pop("103")   # Remove roll 103
 
print("\n--- After Removing Student (103) ---")
for r, d in students.items():
    print(r, d)
# Out:
# --- Initial Student Records ---
# 101 {'name': 'Adarsh', 'subjects': {'Python', 'machine learner'}}
# 102 {'name': 'Tanu', 'subjects': {'kannada', 'BIOLOGY'}}
# 103 {'name': 'Arjun', 'subjects': {'Chemistry', 'Social Science'}}
#
# --- After Adding New Student (104) ---
# 101 {'name': 'Adarsh', 'subjects': {'Python', 'machine learner'}}
# 102 {'name': 'Tanu', 'subjects': {'kannada', 'BIOLOGY'}}
# 103 {'name': 'Arjun', 'subjects': {'Chemistry', 'Social Science'}}
# 104 {'name': 'VEEREESH', 'subjects': {'docker', 'Bash'}}
#
# --- After Updating Student (102) ---
# 101 {'name': 'Adarsh', 'subjects': {'Python', 'machine learner'}}
# 102 {'name': 'KISHAN', 'subjects': {'kannada', 'BIOLOGY'}}
# 103 {'name': 'Arjun', 'subjects': {'Chemistry', 'Social Science'}}
# 104 {'name': 'VEEREESH', 'subjects': {'docker', 'Bash'}}
#
# --- After Removing Student (103) ---
# 101 {'name': 'Adarsh', 'subjects': {'Python', 'machine learner'}}
# 102 {'name': 'KISHAN', 'subjects': {'kannada', 'BIOLOGY'}}
# 104 {'name': 'VEEREESH', 'subjects': {'docker', 'Bash'}}
