# %%
first_name = input("Enter your first name: ").strip()
last_name = input("Enter your last name: ").strip()
birth_year = input("Enter your birth year: ").strip()
print(first_name)
print(last_name)
print(birth_year)

a = first_name[:3].lower()      # first 3 letters of first name
b = last_name[-3:].lower()      # last 3 letters of last name
c = birth_year[-2:]             # last 2 digits of birth year
print(a)
print(b)
print(c)
# Step 3: Combine to form username
username = a + b + c
print(username)

# Step 4: Add some variation options
alt_username = first_name[0].upper() + last_name.lower() + str(len(first_name) + len(last_name))

# Step 5: Output results
print("\nYour suggested usernames:")
print(f"😊  {username}")
print(f"😀  {alt_username}")
# Out:
# Adarsh sadfgh
# Vijay
# 2000
# ada
# jay
# 00
# adajay00
#
# Your suggested usernames:
# 😊  adajay00
# 😀  Avijay18
